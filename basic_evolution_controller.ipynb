# %%
# Third-party libraries
import matplotlib.pyplot as plt
import mujoco
import numpy as np
from mujoco import viewer

# import prebuilt robot phenotypes
from ariel.body_phenotypes.robogen_lite.prebuilt_robots.gecko import gecko
from ariel.simulation.environments.olympic_arena import OlympicArena
# Local libraries
from ariel.simulation.tasks.gait_learning import xy_displacement
from ariel.utils.renderers import video_renderer
from ariel.utils.video_recorder import VideoRecorder


def genome_move(model, data, to_track, genome, timestep, history) -> None:
    """
    Applies joint commands from a pre-generated genome.
    
    The genome is a list of lists, where each inner list is a set of
    commands for one timestep.
    """
    delta = 0.05
    data.ctrl += genome[int(data.time / 0.002)] * delta 
    data.ctrl = np.clip(data.ctrl, -np.pi/2, np.pi/2)
# 

    # data.ctrl = genome[int(data.time / 0.002)]

    history.append(to_track[0].xpos.copy())

def create_population(model, num_steps, population):
    return [[np.random.uniform(low=-np.pi/2, high=np.pi/2, size=model.nu) for _ in range(num_steps)] for _ in range(population)]



from multiprocessing import Pool, cpu_count

# --- helper function for pool (must be top-level) ---
def _evaluate_star(args):
    return evaluate_one(*args)


def fitness_function(target_position, history):
    xt, yt, zt = target_position
    distances = [
        np.sqrt((xt - x)**2 + (yt - y)**2 + (zt - z)**2)
        for x, y, z in history
    ]
    return np.mean(distances)  # average distance instead of only final


import time as t
def evaluate_one(genome, robot_core_func, world_func, time, spawn_pos):
    mujoco.set_mjcb_control(None)
    world = world_func()
    world.spawn(robot_core_func().spec, spawn_pos)
    model = world.spec.compile()
    data = mujoco.MjData(model)

    geoms = world.spec.worldbody.find_all(mujoco.mjtObj.mjOBJ_GEOM)
    to_track = [data.bind(geom) for geom in geoms if "core" in geom.name]
    
    timestep = [0]
    history  = []
    mujoco.set_mjcb_control(lambda m,d: genome_move(m, d, to_track, genome, timestep, history))

    while data.time < time and timestep[0] < len(genome):
        mujoco.mj_step(model, data)
        timestep[0] += 1
        
    pos_data = np.array(history)
    distance_to_goal = fitness_function((5, 0, 0.5), history)
        
    return distance_to_goal


def evaluate(population, robot_core_func, world_func, time, spawn_pos, n_workers=None):
    if n_workers is None:
        n_workers = min(len(population), cpu_count() - 1)

    results_fitness = []
    total = len(population)

    with Pool(n_workers) as pool:
        args = [
            (genome, robot_core_func, world_func, time, spawn_pos)
            for genome in population
        ]

        for i, result in enumerate(pool.imap_unordered(_evaluate_star, args), 1):
            results_fitness.append(result)
            print(f"Processed genome {i}/{total} with fitness: {result}")

    return results_fitness



def parent_selection(x, f):
    x_parents, f_parents = [],[]
    
    total_f              = np.sum(f)
    
    s                    = 0.000000000001
    max_probs            = np.array([i / (total_f + s) for i in f])    
    min_probs            = 1 / (max_probs + s)
    min_probs_normalized = min_probs / (min_probs.sum() + s)
    
    for _ in range(int(len(x)/2)):
        parent_indices = np.random.choice(len(x), size=2, replace=True, p=min_probs_normalized)
        x_parents.append([x[i] for i in parent_indices])
        f_parents.append([f[i] for i in parent_indices])

    return x_parents, f_parents

def crossover(x_parents, p_crossover, alpha=0.5):
    offspring = []
    for p1, p2 in x_parents:
        if np.random.rand() > p_crossover:
            offspring.extend([p1, p2])
            continue
        
        child1, child2 = [], []
        for t in range(len(p1)):
            mix = np.random.rand(*p1[t].shape)
            c1 = alpha * p1[t] + (1 - alpha) * p2[t] + 0.1 * np.random.randn(*p1[t].shape)
            c2 = alpha * p2[t] + (1 - alpha) * p1[t] + 0.1 * np.random.randn(*p2[t].shape)
            child1.append(np.clip(c1, -np.pi/2, np.pi/2))
            child2.append(np.clip(c2, -np.pi/2, np.pi/2))
        offspring.extend([np.array(child1), np.array(child2)])
    return np.array(offspring)



def mutate(pop, mutation_rate=0.3, mutation_scale=0.5):
    for i in range(len(pop)):
        for t in range(len(pop[i])):
            if np.random.rand() < mutation_rate:
                noise = np.random.normal(0, mutation_scale, size=pop[i][t].shape)
                pop[i][t] = np.clip(pop[i][t] + noise, -np.pi/2, np.pi/2)
    return pop


def survivior_selection(x, f, x_offspring, f_offspring):
    """Select the survivors, for the population of the next generation. Returns a list of survivors and their fitness values."""

    # 1) This one looks slightly weird since in the provided code the x and f is passed as a parent pair so it needs to be flattend
    _x = []
    for i in x: _x.extend(i)
    
    _f = []
    for i in f: _f.extend(i)
    
    x_offspring = x_offspring.tolist() # For simplicity

    # 2) Get combine population
    combined_x = np.array(_x + x_offspring)
    combined_f = np.array(_f + f_offspring)
    
    # 3) Sort based on best performing
    sorted_indices = np.argsort(combined_f)
    
    # 4) Get n best performing
    n = len(_x)
    x = combined_x[sorted_indices[:n]]
    f = combined_f[sorted_indices[:n]]

    return x, f


def main(world_func, robot_func, spawn_pos = [-0.8, 0, 0.1],time = 30, population = 10, generations = 50, p_crossover = 0.5, m_rate = 0.1):
    """Main function to run the simulation with random movements."""

    mujoco.set_mjcb_control(None) # DO NOT REMOVE
    world       = world_func()
    gecko_core  = robot_func()     # DO NOT CHANGE
    world.spawn(gecko_core.spec, spawn_pos)
    model       = world.spec.compile()
    num_steps   = int(time / model.opt.timestep)

    population  = create_population(model, num_steps, population)
    population_fitness = evaluate(population, robot_func, world_func, time, spawn_pos)

    idx = np.argmin(population_fitness) 
    x0_best = population[idx]
    f0_best = population_fitness[idx]
    
    x_best = [x0_best]
    f_best = [f0_best]

    for _ in range(generations):
        parents, parents_f             = parent_selection(population, population_fitness)
        offsprings                     = crossover(parents, p_crossover)
        
        offsprings                     = mutate(offsprings, m_rate)
        f_offspring                    = evaluate(offsprings, robot_func, world_func, time, spawn_pos)

        elite_idx = np.argmin(population_fitness)
        elite = population[elite_idx]
        elite_fitness = population_fitness[elite_idx]

        population, population_fitness = survivior_selection(
            parents, parents_f, offsprings, f_offspring
        )

        # Ensure elite survives
        worst_idx = np.argmax(population_fitness)
        population[worst_idx] = elite
        population_fitness[worst_idx] = elite_fitness

        idx = np.argmin(population_fitness) # !!! SWITCHED FROM .argmax() to .argmin() FOR MINIMIZATION !!!
        xi_best = population[idx]
        fi_best = population_fitness[idx]
        print(f"Best one is {fi_best}")
        if fi_best < f_best[-1]: # !!! SWITCHED FROM > to < FOR MINIMIZATION !!!
            x_best.append(xi_best)
            f_best.append(fi_best)
        else:
            x_best.append(x_best[-1])
            f_best.append(f_best[-1])
    
    return x_best, f_best


x, a = None, None
if __name__ == "__main__":
    x, a = main(OlympicArena,gecko,time=30, population= 12, generations=80)

    plt.figure(figsize=(10, 6))
    plt.plot(a, 'm-', label='Distance to Target')

    plt.ylim(bottom = 0)
    plt.legend()
    plt.grid(True)
# Out:
# Processed genome 1/12 with fitness: 5.882441503246232
# Processed genome 2/12 with fitness: 5.778630031215294
# Processed genome 3/12 with fitness: 5.750911535073857
# Processed genome 4/12 with fitness: 5.787604157309721
# Processed genome 5/12 with fitness: 5.785892245970617
# Processed genome 6/12 with fitness: 5.861583826584802
# Processed genome 7/12 with fitness: 5.858518875308748
# Processed genome 8/12 with fitness: 5.819570012144411
# Processed genome 9/12 with fitness: 5.815220633123002
# Processed genome 10/12 with fitness: 5.761469241876614
# Processed genome 11/12 with fitness: 5.748911468216364
# Processed genome 12/12 with fitness: 5.742224192419
# Processed genome 1/12 with fitness: 5.865756420397602
# Processed genome 2/12 with fitness: 5.860430942330086
# Processed genome 3/12 with fitness: 5.756355215411878
# Processed genome 4/12 with fitness: 5.814704253006732
# Processed genome 5/12 with fitness: 5.802915654319567
# Processed genome 6/12 with fitness: 5.734309251969095
# Processed genome 7/12 with fitness: 5.858173578066798
# Processed genome 8/12 with fitness: 5.789647473490336
# Processed genome 9/12 with fitness: 5.817577342455645
# Processed genome 10/12 with fitness: 5.874927759311204
# Processed genome 11/12 with fitness: 5.716998755139977
# Processed genome 12/12 with fitness: 5.746050742951217
# Best one is 5.716998755139977
# Processed genome 1/12 with fitness: 5.727327516796574
# Processed genome 2/12 with fitness: 5.815929825520629
# Processed genome 3/12 with fitness: 5.783553472442129
# Processed genome 4/12 with fitness: 5.865622268016546
# Processed genome 5/12 with fitness: 5.783546413172478
# Processed genome 6/12 with fitness: 5.868538955375486
# Processed genome 7/12 with fitness: 5.812285305082945
# Processed genome 8/12 with fitness: 5.707179432158682
# Processed genome 9/12 with fitness: 5.784505194185025
# Processed genome 10/12 with fitness: 5.714865113341764
# Processed genome 11/12 with fitness: 5.7813360332482375
# Processed genome 12/12 with fitness: 5.819161644350464
# Best one is 5.707179432158682
# Processed genome 1/12 with fitness: 5.711288728880331
# Processed genome 2/12 with fitness: 5.780050073251746
# Processed genome 3/12 with fitness: 5.805011249434764
# Processed genome 4/12 with fitness: 5.746796806687689
# Processed genome 5/12 with fitness: 5.71142552707877
# Processed genome 6/12 with fitness: 5.838587979531008
# Processed genome 7/12 with fitness: 5.85662822217761
# Processed genome 8/12 with fitness: 5.7202486019484216
# Processed genome 9/12 with fitness: 5.759194132265884
# Processed genome 10/12 with fitness: 5.7357676406619325
# Processed genome 11/12 with fitness: 5.825953242326502
# Processed genome 12/12 with fitness: 5.824203729085664
# Best one is 5.707179432158682
# Processed genome 1/12 with fitness: 5.74430314209425
# Processed genome 2/12 with fitness: 5.715394485594416
# Processed genome 3/12 with fitness: 5.820014874445314
# Processed genome 4/12 with fitness: 5.668209023894124
# Processed genome 5/12 with fitness: 5.834730947624019
# Processed genome 6/12 with fitness: 5.794253778922085
# Processed genome 7/12 with fitness: 5.717799581368083
# Processed genome 8/12 with fitness: 5.819036194288209
# Processed genome 9/12 with fitness: 5.718584501351123
# Processed genome 10/12 with fitness: 5.716616678678681
# Processed genome 11/12 with fitness: 5.82190834004052
# Processed genome 12/12 with fitness: 5.707076341511996
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.8360810467110165
# Processed genome 2/12 with fitness: 5.834212432581961
# Processed genome 3/12 with fitness: 5.840684129173544
# Processed genome 4/12 with fitness: 5.836386261548901
# Processed genome 5/12 with fitness: 5.829988527949251
# Processed genome 6/12 with fitness: 5.835760128366396
# Processed genome 7/12 with fitness: 5.835432599286276
# Processed genome 8/12 with fitness: 5.836144649482429
# Processed genome 9/12 with fitness: 5.828992803685191
# Processed genome 10/12 with fitness: 5.834371083057491
# Processed genome 11/12 with fitness: 5.833654033353991
# Processed genome 12/12 with fitness: 5.842608612106496
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.84118369866008
# Processed genome 2/12 with fitness: 5.834937876057353
# Processed genome 3/12 with fitness: 5.833331821787572
# Processed genome 4/12 with fitness: 5.8216770963136835
# Processed genome 5/12 with fitness: 5.837935960370428
# Processed genome 6/12 with fitness: 5.836323255655199
# Processed genome 7/12 with fitness: 5.8277353750442025
# Processed genome 8/12 with fitness: 5.8353183211843245
# Processed genome 9/12 with fitness: 5.833829840429482
# Processed genome 10/12 with fitness: 5.837383276239858
# Processed genome 11/12 with fitness: 5.833712161991402
# Processed genome 12/12 with fitness: 5.834886519885075
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.834366531077687
# Processed genome 2/12 with fitness: 5.830103013130821
# Processed genome 3/12 with fitness: 5.831308254155426
# Processed genome 4/12 with fitness: 5.835113227499017
# Processed genome 5/12 with fitness: 5.8367864013299675
# Processed genome 6/12 with fitness: 5.83686530547033
# Processed genome 7/12 with fitness: 5.833397218612181
# Processed genome 8/12 with fitness: 5.835414167646178
# Processed genome 9/12 with fitness: 5.830846812616155
# Processed genome 10/12 with fitness: 5.832623870952946
# Processed genome 11/12 with fitness: 5.83347976139096
# Processed genome 12/12 with fitness: 5.838728639508184
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.8294778477682705
# Processed genome 2/12 with fitness: 5.831879403262126
# Processed genome 3/12 with fitness: 5.836040551029103
# Processed genome 4/12 with fitness: 5.830156281342739
# Processed genome 5/12 with fitness: 5.8362196553569
# Processed genome 6/12 with fitness: 5.834342692817461
# Processed genome 7/12 with fitness: 5.833624065815828
# Processed genome 8/12 with fitness: 5.836565265734637
# Processed genome 9/12 with fitness: 5.828836117282628
# Processed genome 10/12 with fitness: 5.829221708599788
# Processed genome 11/12 with fitness: 5.83581280310044
# Processed genome 12/12 with fitness: 5.831897003121344
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.837841692878551
# Processed genome 2/12 with fitness: 5.840832711577483
# Processed genome 3/12 with fitness: 5.836617000759141
# Processed genome 4/12 with fitness: 5.831009048303432
# Processed genome 5/12 with fitness: 5.8375946773787755
# Processed genome 6/12 with fitness: 5.84386857348609
# Processed genome 7/12 with fitness: 5.837483248001036
# Processed genome 8/12 with fitness: 5.829749152934329
# Processed genome 9/12 with fitness: 5.832688470501573
# Processed genome 10/12 with fitness: 5.829727165164547
# Processed genome 11/12 with fitness: 5.834570794491852
# Processed genome 12/12 with fitness: 5.829698285383583
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.831981560671175
# Processed genome 2/12 with fitness: 5.8386286910273695
# Processed genome 3/12 with fitness: 5.838670627398369
# Processed genome 4/12 with fitness: 5.836796849176939
# Processed genome 5/12 with fitness: 5.837276516315682
# Processed genome 6/12 with fitness: 5.837789894945561
# Processed genome 7/12 with fitness: 5.832862302840351
# Processed genome 8/12 with fitness: 5.837023421760884
# Processed genome 9/12 with fitness: 5.839687966014284
# Processed genome 10/12 with fitness: 5.833615662769318
# Processed genome 11/12 with fitness: 5.829651176852146
# Processed genome 12/12 with fitness: 5.83398919035758
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.832023631568429
# Processed genome 2/12 with fitness: 5.829734603793812
# Processed genome 3/12 with fitness: 5.832383696340148
# Processed genome 4/12 with fitness: 5.828173292962881
# Processed genome 5/12 with fitness: 5.830438286579751
# Processed genome 6/12 with fitness: 5.825329034201214
# Processed genome 7/12 with fitness: 5.84196603701006
# Processed genome 8/12 with fitness: 5.829868560000626
# Processed genome 9/12 with fitness: 5.836340936567365
# Processed genome 10/12 with fitness: 5.830011403295284
# Processed genome 11/12 with fitness: 5.8395665511535615
# Processed genome 12/12 with fitness: 5.829173080605133
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.831102511864096
# Processed genome 2/12 with fitness: 5.828862881669744
# Processed genome 3/12 with fitness: 5.842908322638825
# Processed genome 4/12 with fitness: 5.8365556169473445
# Processed genome 5/12 with fitness: 5.829504262862994
# Processed genome 6/12 with fitness: 5.835385870014405
# Processed genome 7/12 with fitness: 5.843728374043475
# Processed genome 8/12 with fitness: 5.82956591114557
# Processed genome 9/12 with fitness: 5.831965086146423
# Processed genome 10/12 with fitness: 5.831625975662648
# Processed genome 11/12 with fitness: 5.827588563724557
# Processed genome 12/12 with fitness: 5.831949957184119
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.834272956287381
# Processed genome 2/12 with fitness: 5.828949405261057
# Processed genome 3/12 with fitness: 5.827283648196292
# Processed genome 4/12 with fitness: 5.833095651031495
# Processed genome 5/12 with fitness: 5.83121714943968
# Processed genome 6/12 with fitness: 5.829388954208925
# Processed genome 7/12 with fitness: 5.839481852157123
# Processed genome 8/12 with fitness: 5.834499088622303
# Processed genome 9/12 with fitness: 5.830296558087621
# Processed genome 10/12 with fitness: 5.838741501850457
# Processed genome 11/12 with fitness: 5.839465292116375
# Processed genome 12/12 with fitness: 5.840021576201661
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.834607821628428
# Processed genome 2/12 with fitness: 5.842936805824238
# Processed genome 3/12 with fitness: 5.8342594257355955
# Processed genome 4/12 with fitness: 5.8409280449474785
# Processed genome 5/12 with fitness: 5.838259416165874
# Processed genome 6/12 with fitness: 5.833622161675725
# Processed genome 7/12 with fitness: 5.836191606967554
# Processed genome 8/12 with fitness: 5.837553462287406
# Processed genome 9/12 with fitness: 5.83556747747094
# Processed genome 10/12 with fitness: 5.834135457045488
# Processed genome 11/12 with fitness: 5.84043837673102
# Processed genome 12/12 with fitness: 5.832700161061526
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.830947070509016
# Processed genome 2/12 with fitness: 5.831931500256633
# Processed genome 3/12 with fitness: 5.834462062562264
# Processed genome 4/12 with fitness: 5.835248695986964
# Processed genome 5/12 with fitness: 5.830628103893183
# Processed genome 6/12 with fitness: 5.836244779083702
# Processed genome 7/12 with fitness: 5.838055750341757
# Processed genome 8/12 with fitness: 5.845512879801233
# Processed genome 9/12 with fitness: 5.829278774099922
# Processed genome 10/12 with fitness: 5.835827893171712
# Processed genome 11/12 with fitness: 5.83061539593954
# Processed genome 12/12 with fitness: 5.832046646960251
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.835591824064598
# Processed genome 2/12 with fitness: 5.83247113070242
# Processed genome 3/12 with fitness: 5.826779318071608
# Processed genome 4/12 with fitness: 5.83230676956676
# Processed genome 5/12 with fitness: 5.835079291483147
# Processed genome 6/12 with fitness: 5.842119732256341
# Processed genome 7/12 with fitness: 5.838657740563191
# Processed genome 8/12 with fitness: 5.83346294010814
# Processed genome 9/12 with fitness: 5.8293566124037755
# Processed genome 10/12 with fitness: 5.829839675652016
# Processed genome 11/12 with fitness: 5.836039692724231
# Processed genome 12/12 with fitness: 5.835881475510704
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.831864199815806
# Processed genome 2/12 with fitness: 5.826935214779197
# Processed genome 3/12 with fitness: 5.834808822748323
# Processed genome 4/12 with fitness: 5.83564945201501
# Processed genome 5/12 with fitness: 5.835444274129172
# Processed genome 6/12 with fitness: 5.836801897577599
# Processed genome 7/12 with fitness: 5.840796523184016
# Processed genome 8/12 with fitness: 5.830693406385463
# Processed genome 9/12 with fitness: 5.835753587961991
# Processed genome 10/12 with fitness: 5.837453560799635
# Processed genome 11/12 with fitness: 5.82580726756414
# Processed genome 12/12 with fitness: 5.833278441182068
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.832343676917731
# Processed genome 2/12 with fitness: 5.833998708841638
# Processed genome 3/12 with fitness: 5.837628929798083
# Processed genome 4/12 with fitness: 5.8398618879748545
# Processed genome 5/12 with fitness: 5.834673576873731
# Processed genome 6/12 with fitness: 5.838663744467209
# Processed genome 7/12 with fitness: 5.836082572412998
# Processed genome 8/12 with fitness: 5.829125544565109
# Processed genome 9/12 with fitness: 5.836318801414298
# Processed genome 10/12 with fitness: 5.8353545062194305
# Processed genome 11/12 with fitness: 5.83767798875067
# Processed genome 12/12 with fitness: 5.834999066610723
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.838538613191858
# Processed genome 2/12 with fitness: 5.8300692972845205
# Processed genome 3/12 with fitness: 5.834719393870839
# Processed genome 4/12 with fitness: 5.834259879548408
# Processed genome 5/12 with fitness: 5.8403285356327
# Processed genome 6/12 with fitness: 5.8312961800398515
# Processed genome 7/12 with fitness: 5.82568630584085
# Processed genome 8/12 with fitness: 5.844770059787842
# Processed genome 9/12 with fitness: 5.832438322986232
# Processed genome 10/12 with fitness: 5.827007224323888
# Processed genome 11/12 with fitness: 5.837471766924902
# Processed genome 12/12 with fitness: 5.8341538176831635
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.831010295321302
# Processed genome 2/12 with fitness: 5.834537520698393
# Processed genome 3/12 with fitness: 5.832558292147153
# Processed genome 4/12 with fitness: 5.837356496368496
# Processed genome 5/12 with fitness: 5.823158606942188
# Processed genome 6/12 with fitness: 5.843650282353478
# Processed genome 7/12 with fitness: 5.844534515172103
# Processed genome 8/12 with fitness: 5.8340910158361785
# Processed genome 9/12 with fitness: 5.843008302276408
# Processed genome 10/12 with fitness: 5.830644864863151
# Processed genome 11/12 with fitness: 5.8415306496290675
# Processed genome 12/12 with fitness: 5.835665754634268
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.83160561148719
# Processed genome 2/12 with fitness: 5.826804492378834
# Processed genome 3/12 with fitness: 5.840969598264365
# Processed genome 4/12 with fitness: 5.8424014321840065
# Processed genome 5/12 with fitness: 5.839454256185967
# Processed genome 6/12 with fitness: 5.838568377547389
# Processed genome 7/12 with fitness: 5.830000100157509
# Processed genome 8/12 with fitness: 5.833530564040581
# Processed genome 9/12 with fitness: 5.83377789034242
# Processed genome 10/12 with fitness: 5.83968384400666
# Processed genome 11/12 with fitness: 5.832349293019766
# Processed genome 12/12 with fitness: 5.833768408910827
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.826087614415733
# Processed genome 2/12 with fitness: 5.835368606440869
# Processed genome 3/12 with fitness: 5.8337758308674825
# Processed genome 4/12 with fitness: 5.832570922300478
# Processed genome 5/12 with fitness: 5.825729436618794
# Processed genome 6/12 with fitness: 5.835552045541144
# Processed genome 7/12 with fitness: 5.838783374249531
# Processed genome 8/12 with fitness: 5.836484226395339
# Processed genome 9/12 with fitness: 5.824762581263117
# Processed genome 10/12 with fitness: 5.829619548381653
# Processed genome 11/12 with fitness: 5.845413340735928
# Processed genome 12/12 with fitness: 5.829135954301746
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.840841577647608
# Processed genome 2/12 with fitness: 5.8306901547290435
# Processed genome 3/12 with fitness: 5.831775871628101
# Processed genome 4/12 with fitness: 5.8298215484351275
# Processed genome 5/12 with fitness: 5.837806373213985
# Processed genome 6/12 with fitness: 5.83206515584546
# Processed genome 7/12 with fitness: 5.836749979696615
# Processed genome 8/12 with fitness: 5.837435621355831
# Processed genome 9/12 with fitness: 5.825708921196094
# Processed genome 10/12 with fitness: 5.833032638923451
# Processed genome 11/12 with fitness: 5.837292014422119
# Processed genome 12/12 with fitness: 5.835749564691032
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.835339050883385
# Processed genome 2/12 with fitness: 5.8326514343599145
# Processed genome 3/12 with fitness: 5.843407681266813
# Processed genome 4/12 with fitness: 5.829976288132801
# Processed genome 5/12 with fitness: 5.831935602695471
# Processed genome 6/12 with fitness: 5.833252135692747
# Processed genome 7/12 with fitness: 5.826600122550164
# Processed genome 8/12 with fitness: 5.83847939335954
# Processed genome 9/12 with fitness: 5.835716106281296
# Processed genome 10/12 with fitness: 5.830667446317333
# Processed genome 11/12 with fitness: 5.8276592708817425
# Processed genome 12/12 with fitness: 5.832293831576057
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.831583980619739
# Processed genome 2/12 with fitness: 5.834662350674819
# Processed genome 3/12 with fitness: 5.835977247932893
# Processed genome 4/12 with fitness: 5.827791968400973
# Processed genome 5/12 with fitness: 5.840748222812715
# Processed genome 6/12 with fitness: 5.837306976964964
# Processed genome 7/12 with fitness: 5.838337102409329
# Processed genome 8/12 with fitness: 5.833145292471601
# Processed genome 9/12 with fitness: 5.836693539216424
# Processed genome 10/12 with fitness: 5.834122429683116
# Processed genome 11/12 with fitness: 5.826478786502352
# Processed genome 12/12 with fitness: 5.8224116328849
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.838862075935006
# Processed genome 2/12 with fitness: 5.840685519315855
# Processed genome 3/12 with fitness: 5.834465798108091
# Processed genome 4/12 with fitness: 5.828521331390752
# Processed genome 5/12 with fitness: 5.834412014042447
# Processed genome 6/12 with fitness: 5.834351422449841
# Processed genome 7/12 with fitness: 5.830537768317378
# Processed genome 8/12 with fitness: 5.8267923649975675
# Processed genome 9/12 with fitness: 5.8401677900373015
# Processed genome 10/12 with fitness: 5.838626384950241
# Processed genome 11/12 with fitness: 5.837911694157154
# Processed genome 12/12 with fitness: 5.8409361463298435
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.836131739376381
# Processed genome 2/12 with fitness: 5.826558009723548
# Processed genome 3/12 with fitness: 5.8264934341774275
# Processed genome 4/12 with fitness: 5.840397975567185
# Processed genome 5/12 with fitness: 5.834850993181276
# Processed genome 6/12 with fitness: 5.836321498365932
# Processed genome 7/12 with fitness: 5.8414022409306625
# Processed genome 8/12 with fitness: 5.828145768006453
# Processed genome 9/12 with fitness: 5.8352937082076295
# Processed genome 10/12 with fitness: 5.834253643557789
# Processed genome 11/12 with fitness: 5.833024099545759
# Processed genome 12/12 with fitness: 5.83581409558111
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.830964086879484
# Processed genome 2/12 with fitness: 5.834446750281006
# Processed genome 3/12 with fitness: 5.835008543539159
# Processed genome 4/12 with fitness: 5.831413990876698
# Processed genome 5/12 with fitness: 5.839357536905223
# Processed genome 6/12 with fitness: 5.8390611290046115
# Processed genome 7/12 with fitness: 5.839270914640008
# Processed genome 8/12 with fitness: 5.830408954602187
# Processed genome 9/12 with fitness: 5.8382727657791165
# Processed genome 10/12 with fitness: 5.839438275642681
# Processed genome 11/12 with fitness: 5.8412636033522
# Processed genome 12/12 with fitness: 5.83331976605998
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.842022808188207
# Processed genome 2/12 with fitness: 5.824332439451456
# Processed genome 3/12 with fitness: 5.830415937315419
# Processed genome 4/12 with fitness: 5.843979342400819
# Processed genome 5/12 with fitness: 5.835968481193856
# Processed genome 6/12 with fitness: 5.835055937715762
# Processed genome 7/12 with fitness: 5.837397150070856
# Processed genome 8/12 with fitness: 5.837938024695278
# Processed genome 9/12 with fitness: 5.8342346577423445
# Processed genome 10/12 with fitness: 5.835990173198639
# Processed genome 11/12 with fitness: 5.83619247159147
# Processed genome 12/12 with fitness: 5.831128651422583
# Best one is 5.668209023894124
# Processed genome 1/12 with fitness: 5.8375053818772145
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/s4ddo/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/multiprocessin │
# │ g/pool.py:856 in next                                                                            │
# │                                                                                                  │
# │   853 │   def next(self, timeout=None):                                                          │
# │   854 │   │   with self._cond:                                                                   │
# │   855 │   │   │   try:                                                                           │
# │ ❱ 856 │   │   │   │   item = self._items.popleft()                                               │
# │   857 │   │   │   except IndexError:                                                             │
# │   858 │   │   │   │   if self._index == self._length:                                            │
# │   859 │   │   │   │   │   self._pool = None                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:231                                                                                  │
# │                                                                                                  │
# │   228                                                                                            │
# │   229 x, a = None, None                                                                          │
# │   230 if __name__ == "__main__":                                                                 │
# │ ❱ 231 │   x, a = main(OlympicArena,gecko,time=30, population= 12, generations=80)                │
# │   232 │                                                                                          │
# │   233 │   plt.figure(figsize=(10, 6))                                                            │
# │   234 │   plt.plot(a, 'm-', label='Distance to Target')                                          │
# │                                                                                                  │
# │ in main:200                                                                                      │
# │                                                                                                  │
# │   197 │   │   offsprings                     = crossover(parents, p_crossover)                   │
# │   198 │   │                                                                                      │
# │   199 │   │   offsprings                     = mutate(offsprings, m_rate)                        │
# │ ❱ 200 │   │   f_offspring                    = evaluate(offsprings, robot_func, world_func, ti   │
# │   201 │   │                                                                                      │
# │   202 │   │   elite_idx = np.argmin(population_fitness)                                          │
# │   203 │   │   elite = population[elite_idx]                                                      │
# │                                                                                                  │
# │ in evaluate:92                                                                                   │
# │                                                                                                  │
# │    89 │   │   │   for genome in population                                                       │
# │    90 │   │   ]                                                                                  │
# │    91 │   │                                                                                      │
# │ ❱  92 │   │   for i, result in enumerate(pool.imap_unordered(_evaluate_star, args), 1):          │
# │    93 │   │   │   results_fitness.append(result)                                                 │
# │    94 │   │   │   print(f"Processed genome {i}/{total} with fitness: {result}")                  │
# │    95                                                                                            │
# │                                                                                                  │
# │ /home/s4ddo/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/multiprocessin │
# │ g/pool.py:861 in next                                                                            │
# │                                                                                                  │
# │   858 │   │   │   │   if self._index == self._length:                                            │
# │   859 │   │   │   │   │   self._pool = None                                                      │
# │   860 │   │   │   │   │   raise StopIteration from None                                          │
# │ ❱ 861 │   │   │   │   self._cond.wait(timeout)                                                   │
# │   862 │   │   │   │   try:                                                                       │
# │   863 │   │   │   │   │   item = self._items.popleft()                                           │
# │   864 │   │   │   │   except IndexError:                                                         │
# │                                                                                                  │
# │ /home/s4ddo/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/threading.py:3 │
# │ 55 in wait                                                                                       │
# │                                                                                                  │
# │    352 │   │   gotit = False                                                                     │
# │    353 │   │   try:    # restore state no matter what (e.g., KeyboardInterrupt)                  │
# │    354 │   │   │   if timeout is None:                                                           │
# │ ❱  355 │   │   │   │   waiter.acquire()                                                          │
# │    356 │   │   │   │   gotit = True                                                              │
# │    357 │   │   │   else:                                                                         │
# │    358 │   │   │   │   if timeout > 0:                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
mujoco.set_mjcb_control(None) # DO NOT REMOVE
world = OlympicArena()
gecko_core = gecko()     # DO NOT CHANGE
world.spawn(gecko_core.spec, [-0.8, 0, 0.1])
model = world.spec.compile()
data = mujoco.MjData(model) # type: ignore
geoms = world.spec.worldbody.find_all(mujoco.mjtObj.mjOBJ_GEOM)
to_track = [data.bind(geom) for geom in geoms if "core" in geom.name]

timestep = [0]
history = []
mujoco.set_mjcb_control(lambda m,d: genome_move(m, d, to_track, x[-1], timestep, history))


viewer.launch(
    model=model,  # type: ignore
    data=data,
)
# Out:
# Exception in thread Thread-772 (_physics_loop):
# Traceback (most recent call last):
#   File "/home/s4ddo/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/s4ddo/Documents/Masters_Year_1/P1/EvoAI/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/s4ddo/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/s4ddo/Documents/Masters_Year_1/P1/EvoAI/.venv/lib/python3.12/site-packages/mujoco/viewer.py", line 430, in _physics_loop
#     mujoco.mj_step(m, d)
#   File "/tmp/ipykernel_23452/3928741407.py", line 12, in <lambda>
#   File "/tmp/ipykernel_23452/3277646703.py", line 28, in genome_move
# IndexError: index 15000 is out of bounds for axis 0 with size 15000
